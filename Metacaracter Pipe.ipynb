# %% [markdown]
# # Metacaracter Pipe (|)
#
# Pipe em expressões regulares significa `OR`

# %%
from re import match

# %%
match('a|b', 'abc')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
match('a|b', 'bce')
# Out:
# <re.Match object; span=(0, 1), match='b'>
